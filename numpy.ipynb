# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\shirish\desktop\ds\datascience\venv\lib\site-packages (2.4.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\shirish\desktop\ds\datascience\venv\lib\site-packages (25.2)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-25.3

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.0'

# %% [markdown]
# creating array

# %% [markdown]
# in numpy cant use list,set,tuple all in array

# %%
arr = np.random.randint(0,10,size = (3,4,3))

# %%
arr
# Out:
# array([[[9, 0, 3],
#         [4, 7, 6],
#         [8, 5, 1],
#         [2, 1, 9]],
#
#        [[9, 7, 4],
#         [7, 1, 8],
#         [7, 2, 5],
#         [5, 4, 4]],
#
#        [[4, 0, 6],
#         [8, 3, 7],
#         [9, 8, 6],
#         [9, 4, 9]]], dtype=int32)

# %%
arr[0]
# Out:
# array([[9, 0, 3],
#        [4, 7, 6],
#        [8, 5, 1],
#        [2, 1, 9]], dtype=int32)

# %%
arr[:2,:]
# Out:
# array([[[9, 0, 3],
#         [4, 7, 6],
#         [8, 5, 1],
#         [2, 1, 9]],
#
#        [[9, 7, 4],
#         [7, 1, 8],
#         [7, 2, 5],
#         [5, 4, 4]]], dtype=int32)

# %%
dataset = np.random.randint(0,255,(16,3,720,720))

# %%
dataset
# Out:
# array([[[[245, 133, 132, ..., 160, 104, 106],
#          [ 18,  20, 146, ...,  54,  88,  51],
#          [ 88, 109,  73, ..., 220,  47, 174],
#          ...,
#          [206,  59, 117, ..., 177, 149, 219],
#          [187,  75, 182, ...,  64, 104, 189],
#          [  6, 214, 216, ..., 224,  56,  94]],
#
#         [[211,  98,  62, ..., 110,  38, 118],
#          [231,  42,  42, ..., 157,   5,  27],
#          [ 34, 241, 144, ...,  99,  77, 103],
#          ...,
#          [  2,  68,  51, ...,  34, 106,  47],
#          [ 53,   3, 170, ...,  60,  10,  73],
#          [ 39,  27,  11, ...,  96,  75, 247]],
#
#         [[224, 167,  60, ..., 185, 204,  55],
#          [121, 174,  31, ...,  83,  36, 126],
#          [ 40, 135, 178, ..., 213, 236,  99],
#          ...,
#          [ 98,  10, 236, ..., 218, 165,  51],
#          [172, 239, 150, ..., 135, 170,  91],
#          [141, 154,  82, ..., 184,  73, 215]]],
#
#
#        [[[161, 141, 177, ...,  10,  24, 141],
#          [ 47,  65,  28, ..., 201, 172, 205],
#          [227, 179,   3, ...,   0,  40, 152],
#          ...,
#          [179, 120, 246, ..., 108, 253, 221],
#          [209, 182, 188, ..., 158,  35, 201],
#          [140,  42, 201, ...,  72, 207, 227]],
#
#         [[175,  40, 129, ..., 230, 115,  82],
#          [165,  88,  14, ..., 215, 123, 177],
#          [ 22, 192, 111, ...,  80, 247, 197],
#          ...,
#          [ 79, 151,  29, ..., 237,  71, 134],
#          [ 45, 234,  67, ...,  92, 170,  55],
#          [164,  10,  62, ...,  35, 190,  29]],
#
#         [[ 48, 116, 105, ...,  84, 227,  14],
#          [147, 156, 143, ..., 162, 193,  47],
#          [ 82, 174, 205, ...,  30, 209,  41],
#          ...,
#          [209,  83, 110, ..., 198, 127,   0],
#          [ 85,  39, 112, ..., 142, 142, 125],
#          [185, 116,  64, ..., 214, 125,  33]]],
#
#
#        [[[ 34, 146, 124, ..., 204, 136,  91],
#          [214, 218,  65, ...,  81,  13,   2],
#          [140, 132,  20, ..., 163, 193, 195],
#          ...,
#          [190, 205, 127, ..., 213, 218,  61],
#          [213,  57, 179, ...,  32, 112,   1],
#          [230,  58, 243, ..., 149, 112, 194]],
#
#         [[124, 145,  26, ..., 242, 151, 135],
#          [148, 173,  26, ...,  95,  88, 177],
#          [121, 117,  58, ...,  90, 244, 225],
#          ...,
#          [238, 220,   8, ..., 125, 174, 133],
#          [141, 231,  34, ...,  93,   5, 183],
#          [116, 158, 198, ...,  41, 220,  36]],
#
#         [[143,  19, 237, ...,  62, 121,  58],
#          [164, 131,  46, ...,  58, 134, 204],
#          [ 44,   6, 176, ..., 212, 106, 114],
#          ...,
#          [  1, 163,  34, ...,  75, 211, 221],
#          [211, 242, 237, ..., 190, 117, 218],
#          [145, 124,   2, ...,  32,   3, 125]]],
#
#
#        ...,
#
#
#        [[[ 27, 116, 129, ...,  46, 213,  25],
#          [ 98, 125,  34, ..., 119, 237, 124],
#          [188, 196, 105, ...,   8, 144,  79],
#          ...,
#          [ 14, 225, 113, ..., 177, 249,  99],
#          [251,  49, 212, ..., 236, 198, 202],
#          [235, 175, 124, ...,  26,   4, 245]],
#
#         [[173, 188, 236, ..., 182, 248,  40],
#          [ 79, 109, 101, ..., 209, 248,  48],
#          [210,  80, 209, ..., 161,  23, 133],
#          ...,
#          [ 99, 152,  64, ...,  39,  44, 170],
#          [136,  20,  40, ..., 132,  41, 139],
#          [ 39, 209, 177, ..., 154, 178,  11]],
#
#         [[ 74, 249,  14, ..., 170, 222, 130],
#          [ 89, 162,  84, ..., 143, 237, 149],
#          [ 64,  74, 101, ..., 109, 117,  76],
#          ...,
#          [ 39,  85, 182, ..., 193,  92,  67],
#          [ 50, 159, 252, ..., 203,  42,  96],
#          [252, 137,  61, ..., 125, 209, 242]]],
#
#
#        [[[188,  58,  80, ..., 109,  46, 250],
#          [206, 173, 166, ...,  27,  62, 141],
#          [101, 191, 108, ..., 228,  31, 220],
#          ...,
#          [ 73, 218, 174, ..., 141,  16, 241],
#          [252, 185,  32, ..., 224,  35,  33],
#          [245,  80,  63, ..., 219,  44, 223]],
#
#         [[150,  21,  56, ...,  86,  36, 254],
#          [  9,  80,  53, ...,   4, 119, 167],
#          [227,  72,  18, ..., 109, 122, 180],
#          ...,
#          [ 80, 224, 166, ...,  28, 208,  16],
#          [230, 236, 236, ...,  21, 190, 219],
#          [239, 149, 189, ..., 109, 210,  97]],
#
#         [[252, 112,  12, ...,   3, 222, 168],
#          [236,  53, 188, ...,  51,  51,  23],
#          [224, 202, 235, ...,  54, 140, 253],
#          ...,
#          [119, 101, 201, ..., 184, 221, 198],
#          [ 66, 144, 212, ..., 191, 178, 238],
#          [194, 101, 158, ...,  85, 149,   6]]],
#
#
#        [[[251,  58,  13, ...,   3, 197,  50],
#          [ 51,  81,  68, ..., 165, 105,  13],
#          [118, 136, 187, ..., 210, 109, 208],
#          ...,
#          [ 65, 156, 131, ...,  73, 241,  49],
#          [ 85, 121,  75, ..., 183,  61, 133],
#          [151,  27,  10, ..., 174, 200, 244]],
#
#         [[ 51, 212, 162, ...,  68, 197,  64],
#          [200,  24,  27, ..., 115,   1, 105],
#          [106, 109, 189, ..., 144, 174, 203],
#          ...,
#          [112, 156,  80, ...,  68,  16,  66],
#          [ 78, 184,   9, ...,  18,  75,  87],
#          [ 39,  15, 168, ..., 243, 180, 197]],
#
#         [[ 67,   9, 109, ...,  27, 136,  83],
#          [ 19,  76,  50, ..., 131, 126, 167],
#          [217, 225, 125, ..., 196,  15,  74],
#          ...,
#          [183, 117,  68, ..., 171,  70, 161],
#          [202, 100, 137, ..., 226,  25,  16],
#          [227,  35, 129, ...,   8,  77, 238]]]],
#       shape=(16, 3, 720, 720), dtype=int32)

# %%
dataset[0]
# Out:
# array([[[245, 133, 132, ..., 160, 104, 106],
#         [ 18,  20, 146, ...,  54,  88,  51],
#         [ 88, 109,  73, ..., 220,  47, 174],
#         ...,
#         [206,  59, 117, ..., 177, 149, 219],
#         [187,  75, 182, ...,  64, 104, 189],
#         [  6, 214, 216, ..., 224,  56,  94]],
#
#        [[211,  98,  62, ..., 110,  38, 118],
#         [231,  42,  42, ..., 157,   5,  27],
#         [ 34, 241, 144, ...,  99,  77, 103],
#         ...,
#         [  2,  68,  51, ...,  34, 106,  47],
#         [ 53,   3, 170, ...,  60,  10,  73],
#         [ 39,  27,  11, ...,  96,  75, 247]],
#
#        [[224, 167,  60, ..., 185, 204,  55],
#         [121, 174,  31, ...,  83,  36, 126],
#         [ 40, 135, 178, ..., 213, 236,  99],
#         ...,
#         [ 98,  10, 236, ..., 218, 165,  51],
#         [172, 239, 150, ..., 135, 170,  91],
#         [141, 154,  82, ..., 184,  73, 215]]],
#       shape=(3, 720, 720), dtype=int32)

# %%
  b = np.random.randint(0,3,(3,4))

# %%
b
# Out:
# array([[2, 1, 1, 0],
#        [2, 0, 1, 2],
#        [0, 2, 0, 0]], dtype=int32)

# %%
  a = np.random.randint(0,3,(4,3))

# %%
a
# Out:
# array([[0, 0, 1],
#        [0, 2, 2],
#        [2, 1, 0],
#        [0, 1, 0]], dtype=int32)

# %%
res = np.dot(b,a)

# %%
res
# Out:
# array([[2, 3, 4],
#        [2, 3, 2],
#        [0, 4, 4]], dtype=int32)

# %%
import numpy as np

# %%
import time

# %%
a =

# %%
st = time.time()

res = a * b

end = time.time()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 st = time.time()
# ----> 3 res = a * b
#       5 end = time.time()
#
# NameError: name 'a' is not defined

# %%
print
