# %%
my_nam = { 
    "name" : "Shirish Sthapit"
}

# %%
my_nam
# Out:
# {'name': 'Shirish Sthapit'}

# %%
person = {
    "name": "Hari Baral",
    "age" : 30,
    "gender" : "Male",
    "pet" : True,
    1 : ["Maths", "science"]
}

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'gender', 'pet', 1])

# %%
person[1]
# Out:
# ['Maths', 'science']

# %%
person["age"]
# Out:
# 30

# %%
person.get("dob")

# %%
person.get("dob",1990)
# Out:
# 1990

# %%
 print(person)
# Out:
# {'name': 'Hari Baral', 'age': 30, 'gender': 'Male', 'pet': True, 1: ['Maths', 'science']}

# %%
person ["age"] = 60

# %%
person.values()
# Out:
# dict_values(['Hari Baral', 60, 'Male', True, ['Maths', 'science']])

# %%
person
# Out:
# {'name': 'Hari Baral',
#  'age': 60,
#  'gender': 'Male',
#  'pet': True,
#  1: ['Maths', 'science']}

# %%
person["city"] = "ktm"

# %%
person
# Out:
# {'name': 'Hari Baral',
#  'age': 60,
#  'gender': 'Male',
#  'pet': True,
#  1: ['Maths', 'science'],
#  'city': 'ktm'}

# %%
person[1].pop(0)
# Out:
# 'Maths'

# %%
person
# Out:
# {'name': 'Hari Baral',
#  'age': 60,
#  'gender': 'Male',
#  'pet': True,
#  1: ['science'],
#  'city': 'ktm'}
