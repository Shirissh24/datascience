# %%
import pandas as pd

columns_name = [
    "time", "gender", "matric_%", "study_year","faculty","gpa_2023","accomodation","allowance","scholarship","study_hours",
    "party_week","drinks_night","missed_classes", "failed_classes", "in_relationship","parent_approve","relation_parent"
]
student_data = pd.read_csv("survey_student.csv",names = columns_name,header = 0)
student_data.head(20)
# Out:
#                          time  gender  matric_% study_year  \
# 0   2024/03/07 5:12:01 pm EET  Female      76.0   2nd Year
# 1   2024/03/07 5:12:08 pm EET    Male      89.0   2nd Year
# 2   2024/03/07 5:12:25 pm EET    Male      76.0   1st Year
# 3   2024/03/07 5:12:28 pm EET    Male      89.0   2nd Year
# 4   2024/03/07 5:13:00 pm EET  Female      74.0   2nd Year
# 5   2024/03/07 5:13:18 pm EET    Male      83.0        NaN
# 6   2024/03/07 5:13:22 pm EET    Male      80.0   2nd Year
# 7   2024/03/07 5:13:26 pm EET  Female      85.0   2nd Year
# 8   2024/03/07 5:13:28 pm EET    Male      89.0        NaN
# 9   2024/03/07 5:13:35 pm EET    Male      83.0        NaN
# 10  2024/03/07 5:14:04 pm EET  Female      75.0        NaN
# 11  2024/03/07 5:14:06 pm EET  Female      80.0   2nd Year
# 12  2024/03/07 5:14:08 pm EET    Male      79.0   2nd Year
# 13  2024/03/07 5:14:10 pm EET  Female      72.0   2nd Year
# 14  2024/03/07 5:14:35 pm EET    Male      78.0        NaN
# 15  2024/03/07 5:14:43 pm EET  Female      87.0   1st Year
# 16  2024/03/07 5:14:50 pm EET  Female      86.0        NaN
# 17  2024/03/07 5:14:51 pm EET    Male      74.0   1st Year
# 18  2024/03/07 5:15:05 pm EET  Female      83.0        NaN
# 19  2024/03/07 5:15:08 pm EET    Male      69.0   2nd Year
#
#                            faculty  gpa_2023  \
# 0           Arts & Social Sciences      72.0
# 1   Economic & Management Sciences      75.0
# 2                     AgriSciences      55.0
# 3                      Engineering      84.0
# 4           Arts & Social Sciences      52.0
# 5                      Engineering       NaN
# 6   Economic & Management Sciences      54.0
# 7           Arts & Social Sciences      75.0
# 8                      Engineering       NaN
# 9                          Science       NaN
# 10                    AgriSciences       NaN
# 11          Arts & Social Sciences      75.0
# 12  Economic & Management Sciences      64.0
# 13  Economic & Management Sciences      76.0
# 14                         Science       NaN
# 15                         Science      75.0
# 16                     Engineering       NaN
# 17  Economic & Management Sciences      65.0
# 18    Medicine and Health Services       NaN
# 19          Arts & Social Sciences      55.0
#
#                                        accomodation        allowance  \
# 0   Private accommodation/ stay with family/friends   R 4001- R 5000
# 1   Private accommodation/ stay with family/friends  R 7001 - R 8000
# 2   Private accommodation/ stay with family/friends   R 4001- R 5000
# 3   Private accommodation/ stay with family/friends  R 6001 - R 7000
# 4   Private accommodation/ stay with family/friends   R 4001- R 5000
# 5   Private accommodation/ stay with family/friends  R 6001 - R 7000
# 6   Private accommodation/ stay with family/friends  R 5001 - R 6000
# 7   Private accommodation/ stay with family/friends  R 5001 - R 6000
# 8                                               NaN  R 5001 - R 6000
# 9                                               NaN  R 6001 - R 7000
# 10                                              NaN   R 4001- R 5000
# 11  Private accommodation/ stay with family/friends  R 6001 - R 7000
# 12  Private accommodation/ stay with family/friends  R 5001 - R 6000
# 13  Private accommodation/ stay with family/friends  R 6001 - R 7000
# 14                                              NaN              NaN
# 15  Private accommodation/ stay with family/friends   R 4001- R 5000
# 16  Private accommodation/ stay with family/friends              NaN
# 17  Private accommodation/ stay with family/friends  R 5001 - R 6000
# 18  Private accommodation/ stay with family/friends              NaN
# 19  Private accommodation/ stay with family/friends  R 6001 - R 7000
#
#             scholarship study_hours     party_week drinks_night  \
# 0                    No          8+  Only weekends           8+
# 1   Yes (NSFAS, etc...)          8+  Only weekends          3-5
# 2                    No         3-5              2           8+
# 3                    No         3-5              3           8+
# 4                    No         3-5  Only weekends          5-8
# 5                    No          8+             4+          3-5
# 6                    No          8+              2          5-8
# 7                    No         3-5              3          3-5
# 8                    No          8+  Only weekends          3-5
# 9                    No         3-5              3          5-8
# 10                   No         5-8              2          5-8
# 11                   No          8+              3           8+
# 12                   No         3-5              2          3-5
# 13                   No         1-3              1          3-5
# 14                  NaN         3-5              2          5-8
# 15                   No          8+  Only weekends          1-3
# 16                   No         3-5              1          3-5
# 17                   No         1-3             4+          5-8
# 18                   No          8+  Only weekends          1-3
# 19                   No         5-8  Only weekends          5-8
#
#    missed_classes failed_classes in_relationship parent_approve  \
# 0               3              0             Yes            Yes
# 1              4+              0              No            Yes
# 2               3              0              No            Yes
# 3               2              0             Yes            Yes
# 4               1              3              No            Yes
# 5               3              1             Yes            Yes
# 6               1              0              No            Yes
# 7               2              0             Yes            Yes
# 8               0            NaN              No            Yes
# 9              4+              0              No            Yes
# 10              0              0              No            Yes
# 11              0              0              No            Yes
# 12              2             4+              No            Yes
# 13              0              0             Yes            Yes
# 14              0              0              No            Yes
# 15              0              0              No            Yes
# 16              0              0              No            Yes
# 17              0              0             Yes            Yes
# 18              0              0             Yes            Yes
# 19              3              3              No            Yes
#
#    relation_parent
# 0       Very close
# 1       Very close
# 2       Very close
# 3       Very close
# 4             Fair
# 5       Very close
# 6       Very close
# 7       Very close
# 8       Very close
# 9            Close
# 10           Close
# 11           Close
# 12      Very close
# 13      Very close
# 14      Very close
# 15      Very close
# 16            Fair
# 17      Very close
# 18      Very close
# 19      Very close
